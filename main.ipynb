# %% [markdown]
# <a href="https://colab.research.google.com/github/JulietteGoardon/lab-data-cleaning/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import users table:

# %%
Users = pd.read_csv("users_table.csv")
Users
# Out:
#           Id  Reputation         CreationDate     DisplayName  \
# 0         -1           1  2010-07-19 06:55:26       Community
# 1          2         101  2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101  2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101  2010-07-19 19:03:27          Emmett
# 4          5        6792  2010-07-19 19:03:57           Shane
# ...      ...         ...                  ...             ...
# 40320  55743           1  2014-09-13 21:03:50       AussieMeg
# 40321  55744           6  2014-09-13 21:39:30       Mia Maria
# 40322  55745         101  2014-09-13 23:45:27    tronbabylove
# 40323  55746         106  2014-09-14 00:29:41             GPP
# 40324  55747           1  2014-09-14 01:01:44  Shivam Agrawal
#
#             LastAccessDate                      WebsiteUrl  \
# 0      2010-07-19 06:55:26  http://meta.stackexchange.com/
# 1      2013-11-12 22:07:23        http://stackoverflow.com
# ...

# %% [markdown]
# #### 3. Rename Id column to userId

# %%
Users = Users.rename(columns={"Id": "userId"})

Users
# Out:
#        userId  Reputation         CreationDate     DisplayName  \
# 0          -1           1  2010-07-19 06:55:26       Community
# 1           2         101  2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101  2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101  2010-07-19 19:03:27          Emmett
# 4           5        6792  2010-07-19 19:03:57           Shane
# ...       ...         ...                  ...             ...
# 40320   55743           1  2014-09-13 21:03:50       AussieMeg
# 40321   55744           6  2014-09-13 21:39:30       Mia Maria
# 40322   55745         101  2014-09-13 23:45:27    tronbabylove
# 40323   55746         106  2014-09-14 00:29:41             GPP
# 40324   55747           1  2014-09-14 01:01:44  Shivam Agrawal
#
#             LastAccessDate                      WebsiteUrl  \
# 0      2010-07-19 06:55:26  http://meta.stackexchange.com/
# 1      2013-11-12 22:07:23        http://stackoverflow.com
# ...

# %% [markdown]
# #### 4. Import posts table:

# %%
Posts = pd.read_csv("posts_table.csv")
Posts
# Out:
#           Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0          1           1              15.0  2010-07-19 19:12:12     23
# 1          2           1              59.0  2010-07-19 19:12:57     22
# 2          3           1               5.0  2010-07-19 19:13:28     54
# 3          4           1             135.0  2010-07-19 19:13:31     13
# 4          5           2               NaN  2010-07-19 19:14:43     81
# ...      ...         ...               ...                  ...    ...
# 39995  48321           2               NaN  2013-01-23 09:00:01      0
# 39996  48322           2               NaN  2013-01-23 09:09:34      3
# 39997  48323           2               NaN  2013-01-23 09:16:44      1
# 39998  48324           2               NaN  2013-01-23 09:36:07      3
# 39999  48325           1               NaN  2013-01-23 09:44:07     -1
#
#        ViewCount                                               Body  \
# ...

# %% [markdown]
# #### 5. Rename Id column to postId and OwnerUserId to userId

# %%
Posts = Posts.rename(columns={"Id": "postId", "OwnerUserId": "userId"})
Posts
# Out:
#        postId  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0           1           1              15.0  2010-07-19 19:12:12     23
# 1           2           1              59.0  2010-07-19 19:12:57     22
# 2           3           1               5.0  2010-07-19 19:13:28     54
# 3           4           1             135.0  2010-07-19 19:13:31     13
# 4           5           2               NaN  2010-07-19 19:14:43     81
# ...       ...         ...               ...                  ...    ...
# 39995   48321           2               NaN  2013-01-23 09:00:01      0
# 39996   48322           2               NaN  2013-01-23 09:09:34      3
# 39997   48323           2               NaN  2013-01-23 09:16:44      1
# 39998   48324           2               NaN  2013-01-23 09:36:07      3
# 39999   48325           1               NaN  2013-01-23 09:44:07     -1
#
#        ViewCount                                               Body   userId  \
# ...

# %% [markdown]
# #### 6. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userId,ViewCount,CommentCount

# %%
Users = Users[["userId", "Reputation", "Views", "UpVotes", "DownVotes"]]
Posts = Posts[["postId", "Score", "userId", "ViewCount", "CommentCount"]]

display(Users,Posts)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes
# 0          -1           1      0     5007       1920
# 1           2         101     25        3          0
# 2           3         101     22       19          0
# 3           4         101     11        0          0
# 4           5        6792   1145      662          5
# ...       ...         ...    ...      ...        ...
# 40320   55743           1      0        0          0
# 40321   55744           6      1        0          0
# 40322   55745         101      0        0          0
# 40323   55746         106      1        0          0
# 40324   55747           1      0        0          0
#
# [40325 rows x 5 columns]
#        postId  Score   userId  ViewCount  CommentCount
# 0           1     23      8.0     1278.0             1
# 1           2     22     24.0     8198.0             1
# 2           3     54     18.0     3613.0             4
# 3           4     13     23.0     5224.0             2
# ...

# %% [markdown]
# #### 7. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
Merged = Users.merge(Posts, how="right")

Merged
# Out:
#         userId  Reputation   Views  UpVotes  DownVotes  postId  Score  \
# 0          8.0      6764.0  1089.0    604.0       25.0       1     23
# 1         24.0       344.0    48.0     36.0        1.0       2     22
# 2         18.0       128.0     8.0     16.0        0.0       3     54
# 3         23.0       308.0    52.0     34.0        1.0       4     13
# 4         23.0       308.0    52.0     34.0        1.0       5     81
# ...        ...         ...     ...      ...        ...     ...    ...
# 39995  19966.0         1.0     1.0      0.0        0.0   48321      0
# 39996    892.0      2772.0   207.0    167.0        2.0   48322      3
# 39997   2020.0       565.0    80.0     81.0        0.0   48323      1
# 39998  19914.0        63.0     6.0      3.0        0.0   48324      3
# 39999  19968.0         1.0     1.0      0.0        0.0   48325     -1
#
#        ViewCount  CommentCount
# 0         1278.0             1
# 1         8198.0             1
# ...

# %% [markdown]
# #### 8. How many missing values do you have in your merged dataframe? On which columns?

# %%
missing_values = Merged.isnull().sum()
print(missing_values)
# Out:
# userId           1038
# Reputation       1038
# Views            1038
# UpVotes          1038
# DownVotes        1038
# postId              0
# Score               0
# ViewCount       24105
# CommentCount        0
# dtype: int64

# %% [markdown]
# #### 9. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %% [markdown]
# I will clean the value and delete the rows without user data.

# %%
users_null = Merged["userId"].isnull()

users_null
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39995    False
# 39996    False
# 39997    False
# 39998    False
# 39999    False
# Name: userId, Length: 40000, dtype: bool

# %%
import pandas as pd

Merged = Merged.dropna(subset=['userId'])

Merged = Merged.reset_index(drop=True)

Merged
# Out:
#         userId  Reputation   Views  UpVotes  DownVotes  postId  Score  \
# 0          8.0      6764.0  1089.0    604.0       25.0       1     23
# 1         24.0       344.0    48.0     36.0        1.0       2     22
# 2         18.0       128.0     8.0     16.0        0.0       3     54
# 3         23.0       308.0    52.0     34.0        1.0       4     13
# 4         23.0       308.0    52.0     34.0        1.0       5     81
# ...        ...         ...     ...      ...        ...     ...    ...
# 38957  19966.0         1.0     1.0      0.0        0.0   48321      0
# 38958    892.0      2772.0   207.0    167.0        2.0   48322      3
# 38959   2020.0       565.0    80.0     81.0        0.0   48323      1
# 38960  19914.0        63.0     6.0      3.0        0.0   48324      3
# 38961  19968.0         1.0     1.0      0.0        0.0   48325     -1
#
#        ViewCount  CommentCount
# 0         1278.0             1
# 1         8198.0             1
# ...

# %% [markdown]
# #### 10. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
Merged.dtypes
# Out:
# userId          float64
# Reputation      float64
# Views           float64
# UpVotes         float64
# DownVotes       float64
# postId            int64
# Score             int64
# ViewCount       float64
# CommentCount      int64
# dtype: object

# %%
Merged[["userId", "Reputation", "Views", "UpVotes", "DownVotes", "ViewCount"]] = Merged[["userId", "Reputation", "Views", "UpVotes", "DownVotes", "ViewCount"]].fillna(0).astype('int64')
Merged.dtypes
# Out:
# userId          int64
# Reputation      int64
# Views           int64
# UpVotes         int64
# DownVotes       int64
# postId          int64
# Score           int64
# ViewCount       int64
# CommentCount    int64
# dtype: object
