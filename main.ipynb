# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import users table:

# %%
users = pd.read_csv('weather-raw.csv')
users.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# #### 3. Rename Id column to userId

# %%
users = weather.rename(columns = {'id':'userId'})

users.sample(2)
# Out:
#      userId  year  month element  d1  d2  d3  d4    d5  d6  ...  d22   d23  \
# 14  MX17004  2010      8    tmax NaN NaN NaN NaN  29.6 NaN  ...  NaN  26.4
# 8   MX17004  2010      5    tmax NaN NaN NaN NaN   NaN NaN  ...  NaN   NaN
#
#     d24   d25  d26   d27  d28   d29  d30   d31
# 14  NaN  29.7  NaN   NaN  NaN  28.0  NaN  25.4
# 8   NaN   NaN  NaN  33.2  NaN   NaN  NaN   NaN
#
# [2 rows x 35 columns]

# %% [markdown]
# #### 4. Import posts table:

# %%
#column_names = list(df.columns.values)
#column_names

posts = pd.read_csv('posts_table.csv')

posts.head(2)
# Out:
#    Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  ViewCount  \
# 0   1           1              15.0  2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0  2010-07-19 19:12:57     22     8198.0
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
#
#        LasActivityDate                          Title  ... AnswerCount  \
# 0  2010-09-15 21:08:26  Eliciting priors from experts  ...         5.0
# 1  2012-11-12 09:21:54             What is normality?  ...         7.0
#
#    CommentCount  FavoriteCount  LastEditorUserId         LastEditDate  \
# 0             1           14.0               NaN                  NaN
# 1             1            8.0              88.0  2010-08-07 17:56:44
#
#   CommunityOwnedDate ParentId  ClosedDate OwnerDisplayName  \
# ...

# %% [markdown]
# #### 5. Rename Id column to postId and OwnerUserId to userId

# %%
#postsdf.rename(columns = {'Id':'postId', 'OwnerUserId':'userId'})

posts.rename(columns = {'Id': 'postId', 'OwnerUserId': 'userId'}, inplace = True)

posts.head(3)
# Out:
#    postId  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0       1           1              15.0  2010-07-19 19:12:12     23
# 1       2           1              59.0  2010-07-19 19:12:57     22
# 2       3           1               5.0  2010-07-19 19:13:28     54
#
#    ViewCount                                               Body  userId  \
# 0     1278.0  <p>How should I elicit prior distributions fro...     8.0
# 1     8198.0  <p>In many different statistical methods there...    24.0
# 2     3613.0  <p>What are some valuable Statistical Analysis...    18.0
#
#        LasActivityDate                                              Title  \
# 0  2010-09-15 21:08:26                      Eliciting priors from experts
# 1  2012-11-12 09:21:54                                 What is normality?
# 2  2013-05-27 14:48:36  What are some valuable Statistical Analysis op...
#
#    ... AnswerCount  CommentCount  FavoriteCount  LastEditorUserId  \
# ...

# %% [markdown]
# #### 6. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userId,ViewCount,CommentCount

# %%
#new_frame = posts(columns = ('postId','userId'))

users = users[['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
#posts = posts[['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']]

print(users.sample(2))
#print(posts.sample(2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #### 7. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
users_posts_merged = pd.merge(left = users,
                                right = 'posts',
                                left_on = 'userId',
                                right_on = 'userId',
                                how = 'inner'),
users_posts_merged.sample(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-981ae58a3c08> in <module>
#       3                                 left_on = 'userId',
#       4                                 right_on = 'userId',
# ----> 5                                 how = 'inner'),
#       6 users_posts_merged.sample(3)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     626     ):
# ...

# %% [markdown]
# #### 8. How many missing values do you have in your merged dataframe? On which columns?

# %%
users_posts_merged.isna().sum()[users_posts_merged.isna().sum() > 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f001d8ca29a8> in <module>
# ----> 1 users_posts_merged.isna().sum()[users_posts_merged.isna().sum() > 0]
#
# NameError: name 'users_posts_merged' is not defined

# %% [markdown]
# #### 9. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %% [markdown]
# #### 10. Adjust the data types in order to avoid future issues. Which ones should be changed?
