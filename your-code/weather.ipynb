# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
weather = pd.read_csv(r'C:\Users\AAndres\Pictures\ALI\IRONHACK\BOOTCAMP\W2\lab-data-cleaning\weather-raw.csv')

# %%
weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
weather=pd.melt(weather, id_vars = ['id', 'year', 'month','element'], var_name='day', value_name='record')

# %%
weather.sample(20)
# Out:
#           id  year  month element  day  record
# 336  MX17004  2010      4    tmax  d16     NaN
# 496  MX17004  2010      7    tmax  d23     NaN
# 200  MX17004  2010      2    tmax  d10     NaN
# 390  MX17004  2010     10    tmax  d18     NaN
# 57   MX17004  2010      7    tmin   d3    17.5
# 142  MX17004  2010      6    tmax   d7     NaN
# 586  MX17004  2010      8    tmax  d27     NaN
# 433  MX17004  2010      8    tmin  d20     NaN
# 627  MX17004  2010      6    tmin  d29    18.0
# 445  MX17004  2010      3    tmin  d21     NaN
# 394  MX17004  2010     12    tmax  d18     NaN
# 599  MX17004  2010      3    tmin  d28     NaN
# 22   MX17004  2010      1    tmax   d2     NaN
# 387  MX17004  2010      7    tmin  d18     NaN
# 420  MX17004  2010      2    tmax  d20     NaN
# 212  MX17004  2010      8    tmax  d10     NaN
# 534  MX17004  2010      4    tmax  d25     NaN
# 307  MX17004  2010     12    tmin  d14     NaN
# 458  MX17004  2010     11    tmax  d21     NaN
# ...

# %%
weather.isnull().sum()
# Out:
# id           0
# year         0
# month        0
# element      0
# day          0
# record     616
# dtype: int64

# %%
weather.shape
# Out:
# (682, 6)

# %%
weather['day']=weather['day'].str.replace("d","")

# %%
weather
# Out:
#           id  year  month element day  record
# 0    MX17004  2010      1    tmax   1     NaN
# 1    MX17004  2010      1    tmin   1     NaN
# 2    MX17004  2010      2    tmax   1     NaN
# 3    MX17004  2010      2    tmin   1     NaN
# 4    MX17004  2010      3    tmax   1     NaN
# ..       ...   ...    ...     ...  ..     ...
# 677  MX17004  2010     10    tmin  31     NaN
# 678  MX17004  2010     11    tmax  31     NaN
# 679  MX17004  2010     11    tmin  31     NaN
# 680  MX17004  2010     12    tmax  31     NaN
# 681  MX17004  2010     12    tmin  31     NaN
#
# [682 rows x 6 columns]

# %%
weather=weather.dropna()
weather
# Out:
#           id  year  month element day  record
# 20   MX17004  2010     12    tmax   1    29.9
# 21   MX17004  2010     12    tmin   1    13.8
# 24   MX17004  2010      2    tmax   2    27.3
# 25   MX17004  2010      2    tmin   2    14.4
# 40   MX17004  2010     11    tmax   2    31.3
# ..       ...   ...    ...     ...  ..     ...
# 631  MX17004  2010      8    tmin  29    15.3
# 638  MX17004  2010      1    tmax  30    27.8
# 639  MX17004  2010      1    tmin  30    14.5
# 674  MX17004  2010      8    tmax  31    25.4
# 675  MX17004  2010      8    tmin  31    15.4
#
# [66 rows x 6 columns]

# %%
weather.dtypes
# Out:
# id          object
# year         int64
# month        int64
# element     object
# day         object
# record     float64
# dtype: object

# %%
weather['day']=weather['day'].astype('int64')

# %%
weather
# Out:
#           id  year  month element  day  record
# 20   MX17004  2010     12    tmax    1    29.9
# 21   MX17004  2010     12    tmin    1    13.8
# 24   MX17004  2010      2    tmax    2    27.3
# 25   MX17004  2010      2    tmin    2    14.4
# 40   MX17004  2010     11    tmax    2    31.3
# ..       ...   ...    ...     ...  ...     ...
# 631  MX17004  2010      8    tmin   29    15.3
# 638  MX17004  2010      1    tmax   30    27.8
# 639  MX17004  2010      1    tmin   30    14.5
# 674  MX17004  2010      8    tmax   31    25.4
# 675  MX17004  2010      8    tmin   31    15.4
#
# [66 rows x 6 columns]

# %%
weather = (weather.groupby(['month','day','element']).agg({'record':'sum'}).reset_index()).sort_values('month')

# %%
weather
# Out:
#     month  day element  record
# 0       1   30    tmax    27.8
# 1       1   30    tmin    14.5
# 2       2    2    tmax    27.3
# 3       2    2    tmin    14.4
# 4       2    3    tmax    24.1
# ..    ...  ...     ...     ...
# 55     11    4    tmin    12.0
# 64     12    6    tmax    27.8
# 62     12    1    tmax    29.9
# 63     12    1    tmin    13.8
# 65     12    6    tmin    10.5
#
# [66 rows x 4 columns]
