# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 2. Import users table:

# %%
users = pd.read_csv('users_table.csv')

users.sample(5)
# Out:
#           Id  Reputation         CreationDate   DisplayName  \
# 30787  43101         101  2014-04-04 09:28:40   benjaminRRR
# 30881  43197          16  2014-04-06 14:55:17         Lex88
# 9484   12267         118  2012-06-28 08:55:21  Happy Mittal
# 4167    6033         101  2011-08-29 01:32:44          Noah
# 30109  42409           1  2014-03-23 09:20:10         Mr.Mr
#
#             LastAccessDate                WebsiteUrl    Location  \
# 30787  2014-04-04 09:28:40  http://benjaminranck.com         NaN
# 30881  2014-07-09 18:17:46                       NaN         NaN
# 9484   2013-07-03 09:49:06                       NaN         NaN
# 4167   2013-03-18 23:03:08     http://www.google.com  Boston, MA
# 30109  2014-03-23 09:20:10                       NaN         NaN
#
#                                                  AboutMe  Views  UpVotes  \
# 30787                                                NaN      0        0
# ...

# %% [markdown]
# #### 3. Rename Id column to userId

# %%
users.rename(columns = {'Id':'userId'}, inplace = True)

users.head(2)
# Out:
#    userId  Reputation         CreationDate   DisplayName       LastAccessDate  \
# 0      -1           1  2010-07-19 06:55:26     Community  2010-07-19 06:55:26
# 1       2         101  2010-07-19 14:01:36  Geoff Dalgas  2013-11-12 22:07:23
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\r\n\r\n<p>...      0     5007
# 1  <p>Developer on the StackOverflow team.  Find ...     25        3
#
#    DownVotes  AccountId   Age ProfileImageUrl
# 0       1920         -1   NaN             NaN
# 1          0          2  37.0             NaN

# %% [markdown]
# #### 4. Import posts table:

# %%
posts = pd.read_csv('posts_table.csv')

posts.sample(5)
# Out:
#           Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 20690  22847           2               NaN  2012-02-14 13:32:57      2
# 10656  11606           2               NaN  2011-06-05 20:49:08      5
# 28788  32151           2               NaN  2012-07-12 05:47:00      1
# 6022    6524           1               NaN  2011-01-25 13:28:53      1
# 12254  13377           2               NaN  2011-07-22 15:30:25      4
#
#        ViewCount                                               Body  \
# 20690        NaN  <p>Make it optional to answer the gender quest...
# 10656        NaN  <p>What you do is not a cross validation, rath...
# 28788        NaN  <p>The AUC averages the performance over the w...
# 6022       633.0  <p>fT(t;B,C) = exp(-t/C)-exp(-t/B) / C-B where...
# 12254        NaN  <h1>Usage of the density function is not neces...
#
#        OwnerUserId      LasActivityDate  \
# 20690          NaN  2012-02-14 13:32:57
# 10656         88.0  2011-06-05 20:49:08
# ...

# %% [markdown]
# #### 5. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns = {'Id': 'postId', 'OwnerUserId': 'userId'}, inplace = True)

posts.head(2)
# Out:
#    postId  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0       1           1              15.0  2010-07-19 19:12:12     23
# 1       2           1              59.0  2010-07-19 19:12:57     22
#
#    ViewCount                                               Body  userId  \
# 0     1278.0  <p>How should I elicit prior distributions fro...     8.0
# 1     8198.0  <p>In many different statistical methods there...    24.0
#
#        LasActivityDate                          Title  ... AnswerCount  \
# 0  2010-09-15 21:08:26  Eliciting priors from experts  ...         5.0
# 1  2012-11-12 09:21:54             What is normality?  ...         7.0
#
#    CommentCount  FavoriteCount  LastEditorUserId         LastEditDate  \
# 0             1           14.0               NaN                  NaN
# 1             1            8.0              88.0  2010-08-07 17:56:44
#
#   CommunityOwnedDate ParentId  ClosedDate OwnerDisplayName  \
# ...

# %% [markdown]
# #### 6. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userId,ViewCount,CommentCount

# %%
users = users[['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
posts = posts[['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']]

display(users.head(3),posts.head(3))
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes
# 0      -1           1      0     5007       1920
# 1       2         101     25        3          0
# 2       3         101     22       19          0
#    postId  Score  userId  ViewCount  CommentCount
# 0       1     23     8.0     1278.0             1
# 1       2     22    24.0     8198.0             1
# 2       3     54    18.0     3613.0             4

# %% [markdown]
# #### 7. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
users_posts = pd.merge(left = users, right = posts, left_on = 'userId', right_on = 'userId', how = 'inner')

users_posts.sample(5)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 5068      601       13478   1286      283         17   14533     13
# 3697      364        5442    671      115          2    4555     19
# 10120    1390       10476   1165      602         34    6693      3
# 22814    6579         506     55      298          0   21868      7
# 26337    8041         405     30       42          5   21384      2
#
#        ViewCount  CommentCount
# 5068         NaN             3
# 3697         NaN             5
# 10120        NaN             1
# 22814      758.0             2
# 26337        NaN             1

# %% [markdown]
# #### 8. How many missing values do you have in your merged dataframe? On which columns?

# %%
pd.isnull(users_posts).sum()[pd.isnull(users_posts).sum() > 0]
# Out:
# ViewCount    23572
# dtype: int64

# %%
len(users_posts['ViewCount'])
# Out:
# 38962

# %%
# We have 23.6K missing values out of 39K in the ViewCount column

# %% [markdown]
# #### 9. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
# There are still 15K values which could be interesting to keep, they represent 40% of the column's data
# In this case, it will be better to fill them with the mean

# %%
mean = users_posts['ViewCount'].mean()

# %%
users_posts['ViewCount'].fillna(value= mean, inplace=True)

# %%
pd.isnull(users_posts).sum()[pd.isnull(users_posts).sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
users_posts['ViewCount'].value_counts()
# Out:
# 1196.225991     23572
# 98.000000          43
# 150.000000         43
# 122.000000         42
# 108.000000         41
#                 ...
# 1664.000000         1
# 1337.000000         1
# 64481.000000        1
# 2313.000000         1
# 3357.000000         1
# Name: ViewCount, Length: 3403, dtype: int64

# %% [markdown]
# #### 10. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
users_posts['ViewCount'] = users_posts['ViewCount'].astype('int64')

# %%
users_posts['ViewCount'].dtypes
# Out:
# dtype('float64')

# %%
users_posts['ViewCount'].dtypes
# Out:
# dtype('int64')

# %%
# As all of the values are int, ViewCount datatype had to change from float to int also
