# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import users table:

# %%
users_table = pd.read_csv('datasets/users_table.csv')
users_table
# Out:
#           Id  Reputation         CreationDate     DisplayName  \
# 0         -1           1  2010-07-19 06:55:26       Community
# 1          2         101  2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101  2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101  2010-07-19 19:03:27          Emmett
# 4          5        6792  2010-07-19 19:03:57           Shane
# ...      ...         ...                  ...             ...
# 40320  55743           1  2014-09-13 21:03:50       AussieMeg
# 40321  55744           6  2014-09-13 21:39:30       Mia Maria
# 40322  55745         101  2014-09-13 23:45:27    tronbabylove
# 40323  55746         106  2014-09-14 00:29:41             GPP
# 40324  55747           1  2014-09-14 01:01:44  Shivam Agrawal
#
#             LastAccessDate                      WebsiteUrl  \
# 0      2010-07-19 06:55:26  http://meta.stackexchange.com/
# 1      2013-11-12 22:07:23        http://stackoverflow.com
# ...

# %% [markdown]
# #### 3. Rename Id column to userId

# %%
users_table = users_table.rename(columns={'Id':'userId'})
users_table
# Out:
#        userId  Reputation         CreationDate     DisplayName  \
# 0          -1           1  2010-07-19 06:55:26       Community
# 1           2         101  2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101  2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101  2010-07-19 19:03:27          Emmett
# 4           5        6792  2010-07-19 19:03:57           Shane
# ...       ...         ...                  ...             ...
# 40320   55743           1  2014-09-13 21:03:50       AussieMeg
# 40321   55744           6  2014-09-13 21:39:30       Mia Maria
# 40322   55745         101  2014-09-13 23:45:27    tronbabylove
# 40323   55746         106  2014-09-14 00:29:41             GPP
# 40324   55747           1  2014-09-14 01:01:44  Shivam Agrawal
#
#             LastAccessDate                      WebsiteUrl  \
# 0      2010-07-19 06:55:26  http://meta.stackexchange.com/
# 1      2013-11-12 22:07:23        http://stackoverflow.com
# ...

# %% [markdown]
# #### 4. Import posts table:

# %%
posts_table = pd.read_csv('datasets/posts_table.csv')
posts_table
# Out:
#           Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0          1           1              15.0  2010-07-19 19:12:12     23
# 1          2           1              59.0  2010-07-19 19:12:57     22
# 2          3           1               5.0  2010-07-19 19:13:28     54
# 3          4           1             135.0  2010-07-19 19:13:31     13
# 4          5           2               NaN  2010-07-19 19:14:43     81
# ...      ...         ...               ...                  ...    ...
# 39995  48321           2               NaN  2013-01-23 09:00:01      0
# 39996  48322           2               NaN  2013-01-23 09:09:34      3
# 39997  48323           2               NaN  2013-01-23 09:16:44      1
# 39998  48324           2               NaN  2013-01-23 09:36:07      3
# 39999  48325           1               NaN  2013-01-23 09:44:07     -1
#
#        ViewCount                                               Body  \
# ...

# %% [markdown]
# #### 5. Rename Id column to postId and OwnerUserId to userId

# %%
posts_table = posts_table.rename(columns={'Id':'postId','OwnerUserId':'userId'})
posts_table.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0       1           1              15.0  2010-07-19 19:12:12     23
# 1       2           1              59.0  2010-07-19 19:12:57     22
# 2       3           1               5.0  2010-07-19 19:13:28     54
# 3       4           1             135.0  2010-07-19 19:13:31     13
# 4       5           2               NaN  2010-07-19 19:14:43     81
#
#    ViewCount                                               Body  userId  \
# 0     1278.0  <p>How should I elicit prior distributions fro...     8.0
# 1     8198.0  <p>In many different statistical methods there...    24.0
# 2     3613.0  <p>What are some valuable Statistical Analysis...    18.0
# 3     5224.0  <p>I have two groups of data.  Each with a dif...    23.0
# 4        NaN  <p>The R-project</p>\n\n<p><a href="http://www...    23.0
#
#        LasActivityDate                                              Title  \
# ...

# %% [markdown]
# #### 6. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userId,ViewCount,CommentCount

# %%
users_columns = users_table[['userId','Reputation','Views','UpVotes','DownVotes']]
users_columns
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes
# 0          -1           1      0     5007       1920
# 1           2         101     25        3          0
# 2           3         101     22       19          0
# 3           4         101     11        0          0
# 4           5        6792   1145      662          5
# ...       ...         ...    ...      ...        ...
# 40320   55743           1      0        0          0
# 40321   55744           6      1        0          0
# 40322   55745         101      0        0          0
# 40323   55746         106      1        0          0
# 40324   55747           1      0        0          0
#
# [40325 rows x 5 columns]

# %%
posts_columns = posts_table[['postId', 'Score','userId','ViewCount','CommentCount']]
posts_columns
# Out:
#        postId  Score   userId  ViewCount  CommentCount
# 0           1     23      8.0     1278.0             1
# 1           2     22     24.0     8198.0             1
# 2           3     54     18.0     3613.0             4
# 3           4     13     23.0     5224.0             2
# 4           5     81     23.0        NaN             3
# ...       ...    ...      ...        ...           ...
# 39995   48321      0  19966.0        NaN             0
# 39996   48322      3    892.0        NaN             2
# 39997   48323      1   2020.0        NaN             0
# 39998   48324      3  19914.0        NaN             0
# 39999   48325     -1  19968.0      116.0             4
#
# [40000 rows x 5 columns]

# %% [markdown]
# #### 7. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
merge_df = pd.merge (left = users_columns,
                     right = posts_columns,
                     how = 'inner',
                     left_on = 'userId',
                     right_on = 'userId')

merge_df
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# ...

# %% [markdown]
# #### 8. How many missing values do you have in your merged dataframe? On which columns?

# %%
merge_null = merge_df.isnull().sum()
display(merge_null)
list(merge_null[merge_null>0].index)
# Out:
# userId              0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# postId              0
# Score               0
# ViewCount       23572
# CommentCount        0
# dtype: int64
# ['ViewCount']

# %% [markdown]
# #### 9. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
#table showing only the ViewCount null
view_null = merge_df['ViewCount'].isnull()
merge_df[view_null].sample(20)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 4894      582        2400    293      692         23    3288      5
# 15826    3382        8009   3559      183         24   32453      5
# 22718    6521         121      3        5          0   18508      0
# 292         8        6764   1089      604         25    1438      1
# 9522     1219         353     54       13          2    3554      1
# 10774    1709        1094    230      160          5    9150      1
# 8154      919       87393  20932    11273        779   38731      9
# 31007   11030        1293    147      518          2   34047      0
# 13492    2669        6078    776     1146        351   21739      3
# 15841    3382        8009   3559      183         24   33884      4
# 19345    4856       17791   5927     2122        412   27551     10
# 5671      686       44152   7357     2156         82   15106      0
# 2756      251        7931    984      819          0    1582     11
# ...

# %%
#table showing only the ViewCount that are not null
view_notnull = merge_df['ViewCount'].notnull()
merge_df[view_notnull].sample(20)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 4611      511        1796    516       33          4     949     15
# 38228   17921           1      4        0          0   46198      0
# 10792    1716         176     16        1          0    3997      6
# 23485    6921         166     10        1          0   17227     10
# 30014   10314          26      1        0          0   25715      5
# 8858     1021         167      4       29          0   31486      3
# 32453   11453         175     26       37          1   43114      2
# 19996    5234         739     49       14          2   13494     20
# 3439      319        1994    523       62          0     927     17
# 20494    5462         118      1        1          0   13206      3
# 24635    7291         164     10      100          0   41443     11
# 37610   17118          16      0        0          0   44264      2
# 30475   10669         131     29       13          0   28833      1
# ...

# %%
#The missing data comes from merging the "posts_table" and the "users_table" files.
#The data that we already have could be useful, so we replace the NaN values and turn it into the mean, so we can continue to make calculations.
posts_columns.isnull().sum()
# Out:
# postId              0
# Score               0
# userId           1038
# ViewCount       24105
# CommentCount        0
# dtype: int64

# %%
merge_df['ViewCount'] = merge_df['ViewCount'].fillna(merge_df['ViewCount'].mean())
merge_df
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 0           1196             0
# 1           1196             0
# 2           1196             0
# ...

# %% [markdown]
# #### 10. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
merge_df['Reputation']= merge_df['Reputation'].astype('int64')
merge_df['Views']= merge_df['Views'].astype('int64')
merge_df['UpVotes']= merge_df['UpVotes'].astype('int64')
merge_df['DownVotes']= merge_df['DownVotes'].astype('int64')
merge_df['postId']= merge_df['postId'].astype('int64')
merge_df['Score']= merge_df['Score'].astype('int64')
merge_df['ViewCount']= merge_df['ViewCount'].astype('int64')
merge_df['CommentCount']= merge_df['CommentCount'].astype('int64')

# %%
#we can change the type for the columns except the userId column
