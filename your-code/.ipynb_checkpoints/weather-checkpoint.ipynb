# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd

# %%
weather = pd.read_csv('..\\weather-raw.csv')
weather
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
#  X Y
#A 1 2
#B 3 4

#new_df = (df.stack()
#            .rename_axis(index = ['V1','V2'])
#            .rename('value')
#            .reset_index()
#            .reindex(columns = ['value','V1','V2']))
#print(new_df)

#new_df = (df.rename_axis(index = 'V1')
#            .reset_index()
#            .melt('V1',var_name='V2')
#            .reindex(columns = ['value','V1','V2']))
#print(new_df)

# %%
weather_new = weather.melt(id_vars=['id','year','month']).rename_axis('element')
weather_new.sample(10)
# Out:
#               id  year  month variable value
# element
# 40       MX17004  2010     11       d1   NaN
# 49       MX17004  2010      3       d2   NaN
# 93       MX17004  2010      3       d4   NaN
# 355      MX17004  2010      2      d16   NaN
# 56       MX17004  2010      7       d2   NaN
# 169      MX17004  2010      8       d7   NaN
# 428      MX17004  2010      6      d19   NaN
# 264      MX17004  2010      1      d12   NaN
# 558      MX17004  2010      5      d25   NaN
# 252      MX17004  2010      6      d11   NaN

# %%
weather_new = (weather.rename_axis(index = ['tmin','tmax'])
                    .reset_index()
                    .melt(id_vars=['day'],value_vars=['tmin','tmax'])
                    .reindex(columns = ['id','year','month','day','tmin','tmax'])
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 weather_new = (weather.rename_axis(index = ['tmin','tmax'])
#       2                     .reset_index()
#       3                     .melt(id_vars=['day'],value_vars=['tmin','tmax'])
#       4                     .reindex(columns = ['id','year','month','day','tmin','tmax'])
#       5 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
#     323 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324     return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:1332, in NDFrame.rename_axis(self, mapper, **kwargs)
#    1330         curnames = self._get_axis(axis).names
# ...
