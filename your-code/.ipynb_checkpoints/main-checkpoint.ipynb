# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import users table:

# %%
users = pd.read_csv('users_table.csv')
users.head()
# Out:
#    Id  Reputation         CreationDate   DisplayName       LastAccessDate  \
# 0  -1           1  2010-07-19 06:55:26     Community  2010-07-19 06:55:26
# 1   2         101  2010-07-19 14:01:36  Geoff Dalgas  2013-11-12 22:07:23
# 2   3         101  2010-07-19 15:34:50  Jarrod Dixon  2014-08-08 06:42:58
# 3   4         101  2010-07-19 19:03:27        Emmett  2014-01-02 09:31:02
# 4   5        6792  2010-07-19 19:03:57         Shane  2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\r\n\r\n<p>...      0     5007
# ...

# %% [markdown]
# #### 3. Rename Id column to userId

# %%
users.rename(columns={'Id':'userId'}, inplace=True)

# %%
users.head()
# Out:
#    userId  Reputation         CreationDate   DisplayName       LastAccessDate  \
# 0      -1           1  2010-07-19 06:55:26     Community  2010-07-19 06:55:26
# 1       2         101  2010-07-19 14:01:36  Geoff Dalgas  2013-11-12 22:07:23
# 2       3         101  2010-07-19 15:34:50  Jarrod Dixon  2014-08-08 06:42:58
# 3       4         101  2010-07-19 19:03:27        Emmett  2014-01-02 09:31:02
# 4       5        6792  2010-07-19 19:03:57         Shane  2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\r\n\r\n<p>...      0     5007
# ...

# %% [markdown]
# #### 4. Import posts table:

# %%
posts = pd.read_csv('posts_table.csv')
posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  ViewCount  \
# 0   1           1              15.0  2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0  2010-07-19 19:12:57     22     8198.0
# 2   3           1               5.0  2010-07-19 19:13:28     54     3613.0
# 3   4           1             135.0  2010-07-19 19:13:31     13     5224.0
# 4   5           2               NaN  2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#        LasActivityDate                                              Title  \
# ...

# %% [markdown]
# #### 5. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns={'OwnerUserId':'userId','Id':'postId'}, inplace=True)

# %%
posts.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0       1           1              15.0  2010-07-19 19:12:12     23
# 1       2           1              59.0  2010-07-19 19:12:57     22
# 2       3           1               5.0  2010-07-19 19:13:28     54
# 3       4           1             135.0  2010-07-19 19:13:31     13
# 4       5           2               NaN  2010-07-19 19:14:43     81
#
#    ViewCount                                               Body  userId  \
# 0     1278.0  <p>How should I elicit prior distributions fro...     8.0
# 1     8198.0  <p>In many different statistical methods there...    24.0
# 2     3613.0  <p>What are some valuable Statistical Analysis...    18.0
# 3     5224.0  <p>I have two groups of data.  Each with a dif...    23.0
# 4        NaN  <p>The R-project</p>\n\n<p><a href="http://www...    23.0
#
#        LasActivityDate                                              Title  \
# ...

# %% [markdown]
# #### 6. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userId,ViewCount,CommentCount

# %%
users_df = users[['userId', 'Reputation','Views','UpVotes','DownVotes']].copy()
users_df.head()
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes
# 0      -1           1      0     5007       1920
# 1       2         101     25        3          0
# 2       3         101     22       19          0
# 3       4         101     11        0          0
# 4       5        6792   1145      662          5

# %%
posts_df = posts[['postId', 'Score','userId','ViewCount','CommentCount']].copy()
posts_df.head()
# Out:
#    postId  Score  userId  ViewCount  CommentCount
# 0       1     23     8.0     1278.0             1
# 1       2     22    24.0     8198.0             1
# 2       3     54    18.0     3613.0             4
# 3       4     13    23.0     5224.0             2
# 4       5     81    23.0        NaN             3

# %% [markdown]
# #### 7. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
users_posts = users_df.merge(posts_df, how='inner', on='userId')
users_posts.sample(10)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 22042    6082        1815    265      106          3   33326      4
# 5469      656        2320    203     1273          7    7800      4
# 16727    3835        1329    119      157          1   43289      4
# 32067   11091        1159    140      185          5   35173      4
# 22851    6619           6      1        0          0   16380      1
# 26160    7972       11631   1050     1230        187   46923      1
# 15222    3277       13898   2866      869         12   14032      1
# 10689    1679        3536    382      164          8   15346      1
# 22477    6369         515    111      120          7   18022      6
# 35273   13684         415     30       18          4   36002      3
#
#        ViewCount  CommentCount
# 22042      268.0             0
# 5469         NaN             0
# 16727        NaN             0
# 32067      422.0             0
# 22851      461.0             3
# ...

# %% [markdown]
# #### 8. How many missing values do you have in your merged dataframe? On which columns?

# %%
users_posts.shape
# Out:
# (38962, 9)

# %%
users_posts.describe()
# Out:
#              userId    Reputation         Views       UpVotes     DownVotes  \
# count  38962.000000  38962.000000  38962.000000  38962.000000  38962.000000
# mean    6079.063087   7281.091679   1400.648016    914.799677     43.841050
# std     5224.896435  15164.527714   3423.886887   2296.527060    161.797079
# min       -1.000000      1.000000      0.000000      0.000000      0.000000
# 25%     1317.000000    147.000000     16.000000      4.000000      0.000000
# 50%     4856.000000    909.000000    124.000000     65.000000      1.000000
# 75%     9651.000000   7931.000000   1050.000000    582.000000     16.000000
# max    55226.000000  87393.000000  20932.000000  11442.000000   1920.000000
#
#              postId         Score      ViewCount  CommentCount
# count  38962.000000  38962.000000   15390.000000  38962.000000
# mean   22960.799651      4.083081    1196.225991      2.014630
# std    13696.932471      6.561843    3742.952815      2.674018
# ...

# %%
users_posts.isnull().sum()
# Out:
# userId              0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# postId              0
# Score               0
# ViewCount       23572
# CommentCount        0
# dtype: int64

# %% [markdown]
# #### 9. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
#I would replace the missing values by 0, filling the 60% of that column with median or mean would created biased user data for further analysis.

users_posts[['ViewCount']] = users_posts[['ViewCount']].fillna(0)
users_posts
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 0            0.0             0
# 1            0.0             0
# 2            0.0             0
# ...

# %% [markdown]
# #### 10. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
users_posts.dtypes
# Out:
# userId            int64
# Reputation        int64
# Views             int64
# UpVotes           int64
# DownVotes         int64
# postId            int64
# Score             int64
# ViewCount       float64
# CommentCount      int64
# dtype: object

# %%
users_posts['ViewCount'] = users_posts['ViewCount'].astype('int64')
users_posts['ViewCount'].dtypes
# Out:
# dtype('int64')

# %%
users_posts
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 0              0             0
# 1              0             0
# 2              0             0
# ...

# %% [markdown]
# #### Bonus Question: Create a dataframe with the outliers you have identified in the dataframe and export it to a csv file in your-code folder.

# %%
users_posts.describe()
# Out:
#              userId    Reputation         Views       UpVotes     DownVotes  \
# count  38962.000000  38962.000000  38962.000000  38962.000000  38962.000000
# mean    6079.063087   7281.091679   1400.648016    914.799677     43.841050
# std     5224.896435  15164.527714   3423.886887   2296.527060    161.797079
# min       -1.000000      1.000000      0.000000      0.000000      0.000000
# 25%     1317.000000    147.000000     16.000000      4.000000      0.000000
# 50%     4856.000000    909.000000    124.000000     65.000000      1.000000
# 75%     9651.000000   7931.000000   1050.000000    582.000000     16.000000
# max    55226.000000  87393.000000  20932.000000  11442.000000   1920.000000
#
#              postId         Score      ViewCount  CommentCount
# count  38962.000000  38962.000000   38962.000000  38962.000000
# mean   22960.799651      4.083081     472.509573      2.014630
# std    13696.932471      6.561843    2423.961137      2.674018
# ...
