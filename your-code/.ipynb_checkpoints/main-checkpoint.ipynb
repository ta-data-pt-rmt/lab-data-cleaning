# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# #### 2. Import users table:

# %%
import patoolib
patoolib.extract_archive("datasets.rar")
# Out:
# patool: Extracting datasets.rar ...
# patool: running "C:\Program Files\7-Zip\7z.EXE" x -o.\Unpack_d4bj4oj7 -- datasets.rar
# patool: ... datasets.rar extracted to `datasets1' (multiple files in root).
# 'datasets1'

# %%
users = pd.read_csv(r"C:\Users\AAndres\Pictures\ALI\IRONHACK\BOOTCAMP\W2\lab-data-cleaning\your-code\datasets\users_table.csv")
users
# Out:
#           Id  Reputation         CreationDate     DisplayName  \
# 0         -1           1  2010-07-19 06:55:26       Community
# 1          2         101  2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101  2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101  2010-07-19 19:03:27          Emmett
# 4          5        6792  2010-07-19 19:03:57           Shane
# ...      ...         ...                  ...             ...
# 40320  55743           1  2014-09-13 21:03:50       AussieMeg
# 40321  55744           6  2014-09-13 21:39:30       Mia Maria
# 40322  55745         101  2014-09-13 23:45:27    tronbabylove
# 40323  55746         106  2014-09-14 00:29:41             GPP
# 40324  55747           1  2014-09-14 01:01:44  Shivam Agrawal
#
#             LastAccessDate                      WebsiteUrl  \
# 0      2010-07-19 06:55:26  http://meta.stackexchange.com/
# 1      2013-11-12 22:07:23        http://stackoverflow.com
# ...

# %% [markdown]
# #### 3. Rename Id column to userId

# %%
users.rename(columns={'Id':'userId'}, inplace='True')
users
# Out:
#        userId  Reputation         CreationDate     DisplayName  \
# 0          -1           1  2010-07-19 06:55:26       Community
# 1           2         101  2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101  2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101  2010-07-19 19:03:27          Emmett
# 4           5        6792  2010-07-19 19:03:57           Shane
# ...       ...         ...                  ...             ...
# 40320   55743           1  2014-09-13 21:03:50       AussieMeg
# 40321   55744           6  2014-09-13 21:39:30       Mia Maria
# 40322   55745         101  2014-09-13 23:45:27    tronbabylove
# 40323   55746         106  2014-09-14 00:29:41             GPP
# 40324   55747           1  2014-09-14 01:01:44  Shivam Agrawal
#
#             LastAccessDate                      WebsiteUrl  \
# 0      2010-07-19 06:55:26  http://meta.stackexchange.com/
# 1      2013-11-12 22:07:23        http://stackoverflow.com
# ...

# %% [markdown]
# #### 4. Import posts table:

# %%
posts = pd.read_csv(r"C:\Users\AAndres\Pictures\ALI\IRONHACK\BOOTCAMP\W2\lab-data-cleaning\your-code\datasets\posts_table.csv")
posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  ViewCount  \
# 0   1           1              15.0  2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0  2010-07-19 19:12:57     22     8198.0
# 2   3           1               5.0  2010-07-19 19:13:28     54     3613.0
# 3   4           1             135.0  2010-07-19 19:13:31     13     5224.0
# 4   5           2               NaN  2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#        LasActivityDate                                              Title  \
# ...

# %% [markdown]
# #### 5. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns={'Id':'postId', 'OwnerUserId':'userId'}, inplace='True')
posts
# Out:
#        postId  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0           1           1              15.0  2010-07-19 19:12:12     23
# 1           2           1              59.0  2010-07-19 19:12:57     22
# 2           3           1               5.0  2010-07-19 19:13:28     54
# 3           4           1             135.0  2010-07-19 19:13:31     13
# 4           5           2               NaN  2010-07-19 19:14:43     81
# ...       ...         ...               ...                  ...    ...
# 39995   48321           2               NaN  2013-01-23 09:00:01      0
# 39996   48322           2               NaN  2013-01-23 09:09:34      3
# 39997   48323           2               NaN  2013-01-23 09:16:44      1
# 39998   48324           2               NaN  2013-01-23 09:36:07      3
# 39999   48325           1               NaN  2013-01-23 09:44:07     -1
#
#        ViewCount                                               Body   userId  \
# ...

# %% [markdown]
# #### 6. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userId,ViewCount,CommentCount

# %%
users1 = users[['userId','Reputation','Views','UpVotes','DownVotes']]
posts1 = posts[['postId', 'Score','userId','ViewCount','CommentCount']]
posts1
# Out:
#        postId  Score   userId  ViewCount  CommentCount
# 0           1     23      8.0     1278.0             1
# 1           2     22     24.0     8198.0             1
# 2           3     54     18.0     3613.0             4
# 3           4     13     23.0     5224.0             2
# 4           5     81     23.0        NaN             3
# ...       ...    ...      ...        ...           ...
# 39995   48321      0  19966.0        NaN             0
# 39996   48322      3    892.0        NaN             2
# 39997   48323      1   2020.0        NaN             0
# 39998   48324      3  19914.0        NaN             0
# 39999   48325     -1  19968.0      116.0             4
#
# [40000 rows x 5 columns]

# %% [markdown]
# #### 7. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
union = pd.merge(left = users1,
         right = posts1
)
union
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# ...

# %% [markdown]
# #### 8. How many missing values do you have in your merged dataframe? On which columns?

# %%
union.isnull().sum()
# Out:
# userId              0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# postId              0
# Score               0
# ViewCount       23572
# CommentCount        0
# dtype: int64

# %%
23572/38962*100
# Out:
# 60.499974333966435

# %% [markdown]
# #### 9. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
union[['Reputation', 'Views', 'ViewCount']].sample(10)
# Out:
#        Reputation  Views  ViewCount
# 5039        13478   1286        NaN
# 11148        7461    764        NaN
# 23260          53      7      448.0
# 33048        2555    284        NaN
# 36077           1      0      100.0
# 5924        44152   7357        NaN
# 2432         2496    384        NaN
# 5119        13478   1286        NaN
# 4696         2133    205        NaN
# 14117         306     28      403.0

# %%
union.sort_values('userId').tail()
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 38957      115.0             2
# 38958      326.0             2
# 38959      166.0             0
# 38960     3357.0             5
# 38961        NaN             0

# %%
print(union[['ViewCount']].max(),union[['ViewCount']].min())
union.corr()
# Out:
# ViewCount    175495.0
# dtype: float64 ViewCount    14.0
# dtype: float64
#                 userId  Reputation     Views   UpVotes  DownVotes    postId  \
# userId        1.000000   -0.278208 -0.221194 -0.245545  -0.198552  0.673326
# Reputation   -0.278208    1.000000  0.951911  0.833215   0.618337 -0.054128
# Views        -0.221194    0.951911  1.000000  0.811474   0.650785 -0.057692
# UpVotes      -0.245545    0.833215  0.811474  1.000000   0.657086 -0.097922
# DownVotes    -0.198552    0.618337  0.650785  0.657086   1.000000 -0.036057
# postId        0.673326   -0.054128 -0.057692 -0.097922  -0.036057  1.000000
# Score        -0.186615    0.088255  0.082375  0.095673   0.044990 -0.207169
# ViewCount    -0.129591    0.044090  0.039113  0.029695   0.019902 -0.171422
# CommentCount  0.026451    0.038538  0.055471  0.022333   0.001945  0.025554
#
#                  Score  ViewCount  CommentCount
# userId       -0.186615  -0.129591      0.026451
# ...

# %%
posts.corr()
# Out:
#                     postId  PostTypeId  AcceptedAnswerId     Score  ViewCount  \
# postId            1.000000   -0.066828          0.919851 -0.203255  -0.165390
# PostTypeId       -0.066828    1.000000               NaN -0.040707        NaN
# AcceptedAnswerId  0.919851         NaN          1.000000 -0.202669  -0.160809
# Score            -0.203255   -0.040707         -0.202669  1.000000   0.510027
# ViewCount        -0.165390         NaN         -0.160809  0.510027   1.000000
# userId            0.673326   -0.246425          0.665270 -0.186615  -0.129591
# AnswerCount      -0.238256         NaN         -0.212274  0.603835   0.372436
# CommentCount      0.028143   -0.118566          0.053386  0.148661   0.028501
# FavoriteCount    -0.167329         NaN         -0.141965  0.877779   0.490539
# LastEditorUserId  0.369942    0.054033          0.346209 -0.025515  -0.006236
# ParentId          0.935255         NaN               NaN -0.167168        NaN
#
# ...

# %%
posts[['PostTypeId','ViewCount', 'Title']].sample(20)
# Out:
#        PostTypeId  ViewCount  \
# 18820           4        NaN
# 11990           1     1782.0
# 5396            2        NaN
# 12077           1      820.0
# 9436            4        NaN
# 28839           2        NaN
# 27185           2        NaN
# 36263           1      250.0
# 28476           1      734.0
# 2067            2        NaN
# 4865            2        NaN
# 20794           2        NaN
# 1517            1      294.0
# 20056           2        NaN
# 37201           2        NaN
# 29837           1      987.0
# 38521           2        NaN
# 27420           2        NaN
# 33656           2        NaN
# 25957           1      609.0
#
#                                                    Title
# 18820                                                NaN
# 11990  Is there a boxplot variant for Poisson distrib...
# 5396                                                 NaN
# 12077  Clustering probability distributions - methods...
# ...

# %% [markdown]
# I am going to fill de Nan with 0 because it seems that when a post has 0 views (always for type of PostType!=1), assigns a Nan instead of a 0 that would be the desired value in order to analyse the info for PostType=1.

# %%
union = union.fillna(0)
union
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 0            0.0             0
# 1            0.0             0
# 2            0.0             0
# ...

# %% [markdown]
# #### 10. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
union.dtypes
# Out:
# userId            int64
# Reputation        int64
# Views             int64
# UpVotes           int64
# DownVotes         int64
# postId            int64
# Score             int64
# ViewCount       float64
# CommentCount      int64
# dtype: object

# %%
union[['ViewCount']] = union[['ViewCount']].astype('int64')
union
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 38957   45934          11      1        0          0   34003      1
# 38958   46192          36      1        0          0   40667      5
# 38959   46522         235     13       27          1   17461      3
# 38960   52371         221      2        0          0   27237     24
# 38961   55226         119      2        3          0   16176      1
#
#        ViewCount  CommentCount
# 0              0             0
# 1              0             0
# 2              0             0
# ...

# %%
union.dtypes
# Out:
# userId          int64
# Reputation      int64
# Views           int64
# UpVotes         int64
# DownVotes       int64
# postId          int64
# Score           int64
# ViewCount       int64
# CommentCount    int64
# dtype: object

# %% [markdown]
# #### EXTRA: define outliers

# %%
plt.boxplot(union['ViewCount'])
plt.show()

# %%
union['ViewCount'].describe()
# Out:
# count     38962.000000
# mean        472.509573
# std        2423.961137
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%         253.000000
# max      175495.000000
# Name: ViewCount, dtype: float64

# %%
posts.groupby(['PostTypeId']).agg({'ViewCount':'mean'}).reset_index()
# Out:
#    PostTypeId    ViewCount
# 0           1  1206.583202
# 1           2          NaN
# 2           3          NaN
# 3           4          NaN
# 4           5          NaN
# 5           6          NaN
# 6           7          NaN

# %%
posts.groupby(['PostTypeId']).agg({'ViewCount':'max'}).reset_index()
# Out:
#    PostTypeId  ViewCount
# 0           1   175495.0
# 1           2        NaN
# 2           3        NaN
# 3           4        NaN
# 4           5        NaN
# 5           6        NaN
# 6           7        NaN

# %%
posts.groupby(['PostTypeId']).agg({'ViewCount':'min'}).reset_index()
# Out:
#    PostTypeId  ViewCount
# 0           1       14.0
# 1           2        NaN
# 2           3        NaN
# 3           4        NaN
# 4           5        NaN
# 5           6        NaN
# 6           7        NaN

# %%
posts[['PostTypeId']].value_counts()
# Out:
# PostTypeId
# 2             23569
# 1             15895
# 4               262
# 5               262
# 3                 6
# 6                 4
# 7                 2
# dtype: int64
